# %%
from __future__ import division

import os
import urllib, cStringIO

import numpy as np
import scipy.stats as stats
import pandas as pd
import json
import re

from PIL import Image
import base64
import datetime
import time

# %%
import couchdb

# %% [markdown]
# ### file hierarchy and database connection vars

# %%
# set vars 
auth = pd.read_csv('auth.txt', header = None) 
server_address_input = auth.values[0][0]

# %%
couch = couchdb.Server(server_address_input)
for dbname in couch:
    print(dbname)
# Out:
# _replicator
# _users
# offline-draw
# test
# tsinghua-draw

# %%
db = couch['tsinghua-draw'] 
db.info()
# Out:
# {u'cluster': {u'n': 1, u'q': 8, u'r': 1, u'w': 1},
#  u'compact_running': False,
#  u'data_size': 10213023,
#  u'db_name': u'tsinghua-draw',
#  u'disk_format_version': 7,
#  u'disk_size': 13289093,
#  u'doc_count': 6226,
#  u'doc_del_count': 0,
#  u'instance_start_time': u'0',
#  u'other': {u'data_size': 11575423},
#  u'purge_seq': u'0-g1AAAAFTeJzLYWBg4MhgTmEQTM4vTc5ISXIwNDLXMwBCwxygFFMiQ5L8____sxIZ8CjKYwGSDAeAFFDpfWLULoCo3U-M2gcQtUS5oQGidj5-tUkJQDKpnqCZSQogdfaE1TmA1MVD1GUBAIxiXo4',
#  u'sizes': {u'active': 10213023, u'external': 11575423, u'file': 13289093},
#  u'update_seq': u'6226-g1AAAAFreJzLYWBg4MhgTmEQTM4vTc5ISXIwNDLXMwBCwxygFFMiQ5L8____s5IYGJiZ8KhLUgCSSfYwpZL4lDqAlMbDlCrgU5oAUloPUyqOR2keC5BkaABSQNXzQcqZ3hNUvgCifD9Y-Q-Cyg9AlN8HO4aRoPIHEOUQt0tkAQB6QWD-'}

# %%
## prints all entries in database...
# for id in db:
#     print id 

sketch_dir='drawings_june_27'
if not os.path.exists(sketch_dir):
    os.makedirs(sketch_dir)

# %%
subIDs=[]
for id in db:
    this_doc = db[id]
    if (this_doc['dataType']=='finalImage'):
        subIDs.append(this_doc['subID'])
#         imgData = this_doc['imgData'];
# #         print this_doc['subID']
# #         filestr = base64.b64decode(imgData)
#         fname = os.path.join(sketch_dir,'{}_sketch_{}.png'.format(this_doc['subID'],this_doc['category'],this_doc['date']))
#         with open(fname, "wb") as fh:
#             fh.write(imgData.decode('base64'))

# %%
num_unique_subs = len(np.unique(subIDs))
num_unique_subs
# Out:
# 66

# %%
num_unique_subs = len(np.unique(subIDs))
unique_subs = np.array(np.unique(subIDs))
to_exclude = np.array(['Testagain','Tesr','Test','Test222','Thutesttesttest','Yingwang','test'])
unique_subs_cleaned  = np.delete(unique_subs, to_exclude)
len(unique_subs)
# Out:
# /Users/brialong/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:4: DeprecationWarning: using a non-integer array as obj in delete will result in an error in the future
#   after removing the cwd from sys.path.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-72054a962d13> in <module>()
#       2 unique_subs = np.array(np.unique(subIDs))
#       3 to_exclude = np.array(['Testagain','Tesr','Test','Test222','Thutesttesttest','Yingwang','test'])
# ----> 4 unique_subs_cleaned  = np.delete(unique_subs, to_exclude)
#       5 len(unique_subs)
#
# /Users/brialong/anaconda2/lib/python2.7/site-packages/numpy/lib/function_base.pyc in delete(arr, obj, axis)
#    4863                 "using a non-integer array as obj in delete will result in an "
#    4864                 "error in the future", DeprecationWarning, stacklevel=2)
# -> 4865             obj = obj.astype(intp)
#    4866         keep = ones(N, dtype=bool)
#    4867
#
# ValueError: invalid literal for int() with base 10: 'Testagain'

# %%
## go through all entries and write out if we find an image
for id in db:
    this_doc = db[id]
    if (this_doc['dataType']=='finalImage'):
        print 'found image'
        imgData = this_doc['imgData'];
#         print this_doc['subID']
#         filestr = base64.b64decode(imgData)
        fname = os.path.join(sketch_dir,'{}_sketch_{}.png'.format(this_doc['subID'],this_doc['category'],this_doc['date']))
        with open(fname, "wb") as fh:
            fh.write(imgData.decode('base64'))
# Out:
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image
# found image

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-c3cbfb52cd1a> in <module>()
# ----> 1 this_doc['age']
#
# KeyError: 'age'

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-18-8e3548c68566> in <module>()
# ----> 1 db = couch['test'] # existing
#
# /Users/brialong/anaconda2/lib/python2.7/site-packages/couchdb/client.pyc in __getitem__(self, name)
#     143         """
#     144         db = Database(self.resource(name), name)
# --> 145         db.resource.head() # actually make a request to the database
#     146         return db
#     147
#
# /Users/brialong/anaconda2/lib/python2.7/site-packages/couchdb/http.pyc in head(self, path, headers, **params)
#     555
#     556     def head(self, path=None, headers=None, **params):
# --> 557         return self._request('HEAD', path, headers=headers, **params)
#     558
#     559     def post(self, path=None, body=None, headers=None, **params):
#
# /Users/brialong/anaconda2/lib/python2.7/site-packages/couchdb/http.pyc in _request(self, method, path, body, headers, **params)
#     590         return self.session.request(method, url, body=body,
#     591                                     headers=all_headers,
# --> 592                                     credentials=self.credentials)
#     593
#     594     def _request_json(self, method, path=None, body=None, headers=None, **params):
#
# /Users/brialong/anaconda2/lib/python2.7/site-packages/couchdb/http.pyc in request(self, method, url, body, headers, credentials, num_redirects)
#     293
#     294         path_query = util.urlunsplit(('', '') + util.urlsplit(url)[2:4] + ('',))
# --> 295         conn = self.connection_pool.get(url)
#     296
#     297         def _try_request_with_retries(retries):
#
# /Users/brialong/anaconda2/lib/python2.7/site-packages/couchdb/http.pyc in get(self, url)
#     513                 raise ValueError('%s is not a supported scheme' % scheme)
#     514             conn = cls(host, timeout=self.timeout)
# --> 515             conn.connect()
#     516
#     517         return conn
#
# /Users/brialong/anaconda2/lib/python2.7/httplib.pyc in connect(self)
#    1253             "Connect to a host on a given (SSL) port."
#    1254
# -> 1255             HTTPConnection.connect(self)
#    1256
#    1257             if self._tunnel_host:
#
# /Users/brialong/anaconda2/lib/python2.7/httplib.pyc in connect(self)
#     819         """Connect to the host and port specified in __init__."""
#     820         self.sock = self._create_connection((self.host,self.port),
# --> 821                                            self.timeout, self.source_address)
#     822
#     823         if self._tunnel_host:
#
# /Users/brialong/anaconda2/lib/python2.7/socket.pyc in create_connection(address, timeout, source_address)
#     573
#     574     if err is not None:
# --> 575         raise err
#     576     else:
#     577         raise error("getaddrinfo returns an empty list")
#
# error: [Errno 61] Connection refused

# %%
# set vars 
# auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
# pswd = auth.values[0][0]


# import pymongo as pm
# conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
# db = conn['kiddraw']
# coll = db['Praisedraw_pilot']

# %% [markdown]
# ### Preprocessing data and rendering images

# %% [markdown]
# Notes:
# There are two types of records in the database: 'stroke' and 'finalImage'. This is stored under the key: 'dataType'.
# The 'stroke'-type of record contains the svg string information. Every stroke event is stored as a separate record.
# The session identifier is called "sessionId".

# %%
total_sessions = coll.find().distinct('sessionId') ## this returns ALL sessions in this collection.
print 'We currently have {} total sessions.'.format(len(total_sessions))
# Out:
# We currently have 20 total sessions.

# %%
exclude_ids = [
'test',
'Test',
'']

# %%
sessions_to_render =  coll.find({'$and': [{'dataType':'finalImage'},{'subID': {"$nin": exclude_ids}}]}).distinct('sessionId')
print 'We currently have {} total session after exclusions/tests.'.format(len(sessions_to_render))
# Out:
# We currently have 2 total session after exclusions/tests.

# %%
image_recs = coll.find({'$and': [{'dataType':'finalImage'}]}).sort('startTrialTime')
# Out:
# 1

# %%
really_run_this = 1
if really_run_this:
    
    ## img writing parameters
    imsize = 224
    
    ## desired output: a dataframe that has trials on the rows, and the following columns:
    ## category, age, number of strokes, mean_pixel_intensity, bounding_box_coordinates_LTRB, list of strokes, 
    ## PNG string, submission_time, submission_date
    ## to be saved out as a nice tidy CSV
    session_id = []
    trial_num = []
    category = []
    num_strokes = []
    mean_pixel_intensity = []
    bounding_box_coords = []
    svg = []
    svg_times = []
    png = []
    submit_time = []
    submit_date = []
    draw_duration = []
    draw_duration_strokes = []
    filename = []
    age=[]
    countErr = 0
    condition=[]
    readadble_date = []
    exclude_session_id = []
    include_age = ['age4']

    for s in total_sessions:
        this_collection = coll
        image_recs = this_collection.find({'$and': [{'sessionId':s}, {'dataType':'finalImage'}]}).sort('time')  
        
        for imrec in image_recs:  
                stroke_recs = this_collection.find({'$and': [ 
                                                  {'sessionId':s}, 
                                                  {'dataType':'stroke'},
                                                  {'category': imrec['category']}]}).sort('time')   

                if stroke_recs.count() > 0: ## only include trials if the drawings are not blank            
                    session_id.append(imrec['sessionId'])        
                    trial_num.append(imrec['trialNum']) 
                    category.append(imrec['category'])

                    try:    
                        png.append(imrec['imgData'])
                        submit_time.append(imrec['endTrialTime'])
                        submit_date.append(imrec['date'])
                        age.append(imrec['age'])
                        condition.append(imrec['condition'])
                        filename.append(os.path.join(sketch_dir,'{}_sketch_{}_{}_{}.png'.format(imrec['category'], imrec['sessionId'], imrec['condition'], imrec['age'])))
                        num_strokes.append(stroke_recs.count())
                        draw_duration.append(imrec['endTrialTime'] - imrec['startTrialTime'])

                        _svg = [] # this keeps track of the strokes from THIS final image
                        _svg_times = []
                        for strec in stroke_recs:
                            _svg.append(strec['svg'])
                            _svg_times.append(strec['endStrokeTime'])
                        draw_duration_strokes.append((_svg_times[-1] - _svg_times[0])/1000) ## in seconds

                        ## and write out image data here too
                        imgData = imrec['imgData'];
                        filestr = base64.b64decode(imgData)
                        child_dir = os.path.join(sketch_dir,imrec['sessionId'])
                        if not os.path.exists(child_dir):
                            os.makedirs(child_dir)
                        fname = os.path.join(child_dir,'{}_sketch_{}_{}_{}.png'.format(imrec['category'],imrec['sessionId'],imrec['condition'], imrec['age']))
                        with open(fname, "wb") as fh:
                            fh.write(imgData.decode('base64'))  

                    except Exception as e:
                        print('something went wrong with an image')
                        print e
                        countErr = countErr + 1
                        print imrec['category']
                        child_dir = os.path.join(sketch_dir,'noname')
                        if not os.path.exists(child_dir):
                            os.makedirs(child_dir)
                        fname = os.path.join(child_dir,'{}_sketch_{}_{}.png'.format(imrec['category'], 'noname',imrec['sessionId']))
                        with open(fname, "wb") as fh:
                            fh.write(imgData.decode('base64'))

# %%
## How many session IDs do we have?
count_subs = np.size(np.unique(session_id))
print 'We have {}  subjects after exclusions.'.format(count_subs)

# %%
## How many drawings do we have in each condition?  
print 'We have {} semantic drawings.'.format(condition.count("S"))
print 'We have {} perception drawings.'.format(condition.count("P")

# %% [markdown]
# ## Save out data into a dataframe

# %%
really_run_this = 1 
## compile data
if really_run_this:
    X = pd.DataFrame([session_id,age,trial_num,condition,category,submit_time,submit_date,num_strokes,svg,svg_times,png,draw_duration,avg_stroke_length,filename])
    X = X.transpose()
    X.columns = ['session_id','age','trial_num','condition','category','submit_time','submit_date','num_strokes','svg','svg_times','png','draw_duration', 'avg_stroke_length','filename']
