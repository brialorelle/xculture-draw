# %%
import os, sys

import pymongo as pm
import numpy as np
import scipy.stats as stats
import pandas as pd
import json
import re

import matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import seaborn as sns
sns.set_context('talk')
sns.set_style('white')

from IPython.display import clear_output
import importlib

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
pd.options.mode.chained_assignment = None

# %%
# directory & file hierarchy
proj_dir = os.path.abspath('..')
stim_dir = os.path.join(proj_dir,'stimuli')

# %% [markdown]
# ## load in data
# CDM = Children’s Discovery Museum, San Jose <br>
# THU = Tsinghua University, Beijing

# %%
CDM = pd.read_csv(os.path.join(stim_dir, 'CDM_photodraw_e2_svg_output2022.csv'))
THU = pd.read_csv(os.path.join(stim_dir, 'THU_photodraw_e2_svg_output2022.csv'))
data = CDM.append(THU)

# %%
data.head()
# Out:
#    Unnamed: 0                     session_id     subID   age     category  \
# 0           0  CDM_photodraw_e21540576831945  102618_1  age4  this square
# 1           1  CDM_photodraw_e21540576907849  102618_1  age4  this square
# 2           2  CDM_photodraw_e21540576907849  102618_1  age4   this shape
# 3           3  CDM_photodraw_e21540576907849  102618_1  age4   this shape
# 4           4  CDM_photodraw_e21540576907849  102618_1  age4    rectangle
#
#   condition                                           filename  \
# 0         S  /Users/brialong/Documents/GitHub/devphotodraw/...
# 1         S  /Users/brialong/Documents/GitHub/devphotodraw/...
# 2         S  /Users/brialong/Documents/GitHub/devphotodraw/...
# 3         S  /Users/brialong/Documents/GitHub/devphotodraw/...
# 4         P  /Users/brialong/Documents/GitHub/devphotodraw/...
#
#                    ref_image_name  stroke_count  \
# 0               images/square.png             1
# 1               images/square.png             1
# 2                images/shape.png             1
# 3                images/shape.png             2
# 4  images_photocues/rectangle.png             1
#
#                                                  svg
# 0  M224.71875,503.42188l-8.04107,2.01575l-3.82151...
# 1  M224.71875,503.42188l-8.04107,2.01575l-3.82151...
# 2  M397.71875,396.42188l4,8l1.73384,0.05863l3.071...
# 3  M397.71875,396.42188l4,8l1.73384,0.05863l15.26...
# 4  M18.71875,1.42188l-15.07726,15.62757l-6.53569,...

# %%
## preprocessing
## only grab object category data (not tracing or familiarization data)
data_test = data.loc[data['category'].isin(['watch', 'bike', 'chair', 'car', 'tree', 'rabbit', 
                                            'house', 'cup', 'hat', 'cat', 'bird', 'airplane'])]

data_test['location'] = data_test['session_id'].apply(lambda x:x.split('_')[0])
data_test['location'] = data_test['location'].replace('Tsinghua', 'THU')

data_test = data_test.reset_index(drop=True)

# %%
## cleanup SVG column
data_test['svg'] = data_test['svg'].apply(lambda x:x.split('d=')[-1])

# %%
## how many sketches in each dataset?
print('{} CDM sketches and {} THU sketches'.format(data_test.loc[data_test['location'] == 'CDM']['filename'].nunique(), 
                                                   data_test.loc[data_test['location'] == 'THU']['filename'].nunique()))
print('{} total sketches'.format(data_test['filename'].nunique()))

assert data_test.loc[data_test['location'] == 'CDM']['filename'].nunique() + data_test.loc[data_test['location'] == 'THU']['filename'].nunique() == data_test['filename'].nunique()
# Out:
# 1438 CDM sketches and 1291 THU sketches
# 2729 total sketches

# %%
## first look at things at the sketch-level
df = data_test.groupby('filename').first().reset_index()

# %%
## how many of each category?
counts = df.groupby(['location'])['category'].value_counts()
display(counts)
# Out:
# location  category
# CDM       chair       121
#           cup         121
#           hat         121
#           bike        120
#           bird        120
#           house       120
#           tree        120
#           watch       120
#           car         119
#           cat         119
#           rabbit      119
#           airplane    118
# THU       bike        113
#           airplane    112
#           bird        110
#           cat         109
#           chair       109
#           tree        109
#           hat         108
#           house       107
#           rabbit      105
#           watch       104
#           cup         103
#           car         102
# Name: category, dtype: int64

# %%
## add groups based on 4 traits: animacy, size, familiarity, and artificiality
## The code for the selection can be found here:
# https://github.com/cogtoolslab/photodraw32/blob/master/stimuli/photodraw2x2_generate_stims/select_sketchy_classes_for_photodraw32.ipynb
# create a list of our conditions
conditions = [
    ((df['category'] == 'rabbit') | (df['category'] == 'cat') | (df['category'] == 'bird')), 
    ((df['category'] == 'watch') | (df['category'] == 'cup') | (df['category'] == 'hat')), 
    ((df['category'] == 'chair') | (df['category'] == 'tree') | (df['category'] == 'house')), 
    ((df['category'] == 'bike') | (df['category'] == 'car') | (df['category'] == 'airplane')), 
]

# create a list of the values we want to assign for each condition
values = [
    'animals', 
    'small_objects', 
    'big_objects', 
    'vehicles', 
]

# create a new column and use np.select to assign values to it using our lists as arguments
df['group'] = np.select(conditions, values)

# %%
## IMPORTANT
## which "group" are we generating metadata for?
whichGroup = df.loc[df['group'] == 'animals']
whichGroup = whichGroup.reset_index(drop=True)

## initialize empty dataframe to copy into
G = pd.DataFrame()

## copy data over
reallyRun = True
if reallyRun:
    G = whichGroup.copy()
    G = G.reset_index(drop=True)
print('Generating stims for {} dataset'.format(whichGroup['group'].unique()))
# Out:
# Generating stims for ['animals'] dataset

# %% [markdown]
# ### NOTE TO HOLLY: we also want to counterbalance by site?

# %%
## define array params
subgroups = G['category'].unique()
l = len(subgroups)
m = min((G.groupby(['category']).size()))

## generate empty array
arr = np.zeros((m, l))


# ## define array params
# subgroups = G['location'].unique()
# l = len(subgroups)
# m = min((G.groupby(['location']).size()))

# ## generate empty array
# arr = np.zeros((m, l))

# %%
# shuffle sketches and put into array
for i, subgroup in enumerate(subgroups):
    perm = np.random.permutation(G.index[G['category'] == subgroup])
    arr[:, i] = perm[:m]
    
# name generated bins
G["bin"] = 0

for i in range(m):
    G.loc[arr[i,:], "bin"] = i

# %%
print('How many bins were made? {}'.format(G['bin'].nunique()))
# Out:
# How many bins were made? 224

# %%
## how many sketches per bin?
checker = []
for i, bins in G.groupby('bin'):
    c = bins['filename'].nunique()
    checker.append(c)

C = pd.DataFrame(checker, columns=['numSketch'])
print('How many sketches are in each bin? {}'.format(C['numSketch'].unique()))
# Out:
# How many sketches are in each bin? [13  3]

# %% [markdown]
# ##### important! split bins if necessary - if not, skip

# %%
## visually check the first bin
print('There are {} extra sketches in this first bin, which need to be split out'.format(len(G.loc[G['bin'] == 0])))
G.loc[G['bin'] == 0].reset_index(drop=True)
# Out:
# There are 13 extra sketches in this first bin, which need to be split out
#                                              filename  Unnamed: 0  \
# 0   /Users/brialong/Documents/GitHub/devphotodraw/...         722
# 1   /Users/brialong/Documents/GitHub/devphotodraw/...        6998
# 2   /Users/brialong/Documents/GitHub/devphotodraw/...        5997
# 3   /Users/brialong/Documents/GitHub/devphotodraw/...        4765
# 4   /Users/brialong/Documents/GitHub/devphotodraw/...        2090
# 5   /Users/brialong/Documents/GitHub/devphotodraw/...       11874
# 6   /Users/brialong/Documents/GitHub/devphotodraw/...        8043
# 7   /Users/brialong/Documents/GitHub/devphotodraw/...        8660
# 8   THU_sketches_and_metadata/bird_sketch_Ipad4_TH...        1903
# 9   THU_sketches_and_metadata/bird_sketch_iPad 5-T...         167
# 10  THU_sketches_and_metadata/cat_sketch_Ipad1-THU...        7245
# 11  THU_sketches_and_metadata/cat_sketch_Ipad2 _TH...        5352
# 12  THU_sketches_and_metadata/rabbit_sketch_Ipad 1...        9344
#
#                                     session_id            subID   age  \
# 0                CDM_photodraw_e21541613545900         110718_1  age6
# 1                CDM_photodraw_e21547848462737         011819_7  age7
# 2                CDM_photodraw_e21547672389753         011619_6  age4
# 3                CDM_photodraw_e21547238095569         011109_5  age6
# 4                CDM_photodraw_e21542224706912         111418_6  age7
# 5                CDM_photodraw_e21555102208611         041219_1  age9
# 6                CDM_photodraw_e21548104824451         012119_8  age8
# 7                CDM_photodraw_e21548449754672         012519_3  age8
# 8   Tsinghua_photodraw_production1573785392477     Ipad4_THU4F8  4.57
# 9   Tsinghua_photodraw_production1577171766191    iPad 5-THU9M2  8.01
# 10  Tsinghua_photodraw_production1577170578110     Ipad1-THU9F2  8.21
# 11  Tsinghua_photodraw_production1575530375673   Ipad2 _THU6F20  6.51
# 12  Tsinghua_photodraw_production1576478852964  Ipad 1_THU 6F32  6.66
#
#    category condition                 ref_image_name  stroke_count  \
# 0      bird         P    images_photocues/bird_2.png             1
# 1      bird         P    images_photocues/bird_3.png             1
# 2      bird         S    images_photocues/bird_2.png             1
# 3      bird         S    images_photocues/bird_3.png             1
# 4      bird         S    images_photocues/bird_3.png             1
# 5       cat         P     images_photocues/cat_3.png             1
# 6       cat         S     images_photocues/cat_2.png             1
# 7       cat         S     images_photocues/cat_2.png             1
# 8      bird         P    images_photocues/bird_3.png             1
# 9      bird         S    images_photocues/bird_3.png             1
# 10      cat         P     images_photocues/cat_3.png             1
# 11      cat         S     images_photocues/cat_2.png             1
# 12   rabbit         S  images_photocues/rabbit_2.png             1
#
#                                                   svg location    group  bin
# 0   M332.71875,237.42188l-19.6595,1.42627l-19.1492...      CDM  animals    0
# 1   M328.71875,426.42188l-14.57565,-24.38115l-15.4...      CDM  animals    0
# 2   M150.71875,118.42188l-13,9l-4.8338,9.00207l-3....      CDM  animals    0
# 3   M450.71875,355.42188l-12.30076,-21.65824l-11.6...      CDM  animals    0
# 4   M81.71875,171.42188l17.69992,-17.8237l18.40754...      CDM  animals    0
# 5   M442.71875,290.42188l-0.52135,8.35889l-1.86892...      CDM  animals    0
# 6   M193.71875,383.42188l4,-9l12.8649,-10.32489l15...      CDM  animals    0
# 7   M322.71875,220.42188l-12,11l-1.71155,3.58969l-...      CDM  animals    0
# 8   "M109.21875,319.51563l2.50756,-3.40526l3.62049...      THU  animals    0
# 9   "M151.21875,284.51563l-16.19297,11.08439l-11.2...      THU  animals    0
# 10  "M412.21875,167.51563l-9.28943,-3.98814l-10.58...      THU  animals    0
# 11  "M193.21875,440.42188l-15.15318,1.19815l-13.11...      THU  animals    0
# 12  "M479.21875,181.42188l-4.08716,-8.60758l-5.912...      THU  animals    0

# %%
import math 
num_divide_by = math.ceil(len(G.loc[G['bin'] == 0])/3)

# %%
## need to split the first bin that has too many sketches
need_split = G.loc[G['bin'] == 0]
need_split['filename'].nunique()
# Out:
# 13

# %%
## randomly shuffle and split into 4 new bins
shuffled = need_split.sample(frac=1)
result = np.array_split(shuffled, num_divide_by)

# %%
## subset each new bin
result_1 = result[0]
result_2 = result[1]
result_2['bin'] = G['bin'].max() + 1
result_3 = result[2]
result_3['bin'] = G['bin'].max() + 2
result_4 = result[3]
result_4['bin'] = G['bin'].max() + 3
result_5 = result[4]
result_5['bin'] = G['bin'].max() + 4
# result_6 = result[5]
# result_6['bin'] = G['bin'].max() + 5
# result_7 = result[6]
# result_7['bin'] = G['bin'].max() + 6
# result_8 = result[7]
# result_8['bin'] = G['bin'].max() + 7
# result_9 = result[8]
# result_9['bin'] = G['bin'].max() + 8

display(len(result_1))
display(len(result_2))
display(len(result_3))
display(len(result_4))
display(len(result_5))
# display(len(result_6))
# display(len(result_7))
# display(len(result_8))
# display(len(result_9))
# Out:
# 3
# 3
# 3
# 2
# 2

# %%
extra_result_1 = result_2.tail(1)
extra_result_2 = result_1.tail(1)

result_4 = result_4.append(extra_result_1)
result_4['bin'] = int(result_4.iloc[0]['bin'])

result_5 = result_5.append(extra_result_2)
result_5['bin'] = int(result_5.iloc[0]['bin'])

# %%
## remove first bin, so that we can replace it
G = G[G.bin != 0]

# add the new bins back into the dataframe
G = pd.concat([G, result_1, 
                  result_2, 
                  result_3, 
                  result_4, 
                  result_5]).reset_index(drop=True)

# %%
# visually check the first bin
G.loc[G['bin'] == 0].reset_index(drop=True)
# Out:
#                                             filename  Unnamed: 0  \
# 0  /Users/brialong/Documents/GitHub/devphotodraw/...       11874
# 1  /Users/brialong/Documents/GitHub/devphotodraw/...        5997
# 2  THU_sketches_and_metadata/cat_sketch_Ipad2 _TH...        5352
#
#                                    session_id           subID   age category  \
# 0               CDM_photodraw_e21555102208611        041219_1  age9      cat
# 1               CDM_photodraw_e21547672389753        011619_6  age4     bird
# 2  Tsinghua_photodraw_production1575530375673  Ipad2 _THU6F20  6.51      cat
#
#   condition               ref_image_name  stroke_count  \
# 0         P   images_photocues/cat_3.png             1
# 1         S  images_photocues/bird_2.png             1
# 2         S   images_photocues/cat_2.png             1
#
#                                                  svg location    group  bin
# 0  M442.71875,290.42188l-0.52135,8.35889l-1.86892...      CDM  animals    0
# 1  M150.71875,118.42188l-13,9l-4.8338,9.00207l-3....      CDM  animals    0
# 2  "M193.21875,440.42188l-15.15318,1.19815l-13.11...      THU  animals    0

# %%
## do we have the 4 items in each bin?
checker = []
for i, bins in G.groupby('bin'):
    c = bins['filename'].nunique()
    checker.append(c)

C = pd.DataFrame(checker, columns=['numSketch'])

print('Second check passed! There are {} items in each bin'.format(C['numSketch'].unique()))
assert C['numSketch'].unique() == G["category"].nunique()
# Out:
# Second check passed! There are [3] items in each bin

# %%
## did we retain all our sketches? 
assert G['filename'].nunique() == whichGroup['filename'].nunique()
print('Check passed! There are {} sketches still in our binned dataset'.format(G['filename'].nunique()))
# Out:
# Check passed! There are 682 sketches still in our binned dataset

# %%
## currently there are 3 sketches in each bin
## now we want to group bins, so that there are 9 sketches in a 'bin_9'
numbers = list(range(0, G['bin'].max()+1))
numbers = pd.DataFrame(numbers, columns=['bin'])
numbers['bin_9'] = np.arange(len(numbers)) // 3

regroup_df = G.merge(numbers, left_on='bin', right_on='bin')

# %%
print('How many bins were made? {}'.format(regroup_df['bin_9'].nunique()))
# Out:
# How many bins were made? 76

# %%
## visually look at things
regroup_df.head()
# Out:
#                                             filename  Unnamed: 0  \
# 0  /Users/brialong/Documents/GitHub/devphotodraw/...         886
# 1  /Users/brialong/Documents/GitHub/devphotodraw/...        3540
# 2  THU_sketches_and_metadata/rabbit_sketch_iPad 1...        6771
# 3  /Users/brialong/Documents/GitHub/devphotodraw/...        4008
# 4  /Users/brialong/Documents/GitHub/devphotodraw/...        7306
#
#                                    session_id          subID   age category  \
# 0               CDM_photodraw_e21541799408496       110918_1  age4     bird
# 1               CDM_photodraw_e21547060282520       O10919_1  age4      cat
# 2  Tsinghua_photodraw_production1577171554498  iPad 1_THU9M2  9.03   rabbit
# 3               CDM_photodraw_e21547070395780       010919_7  age4     bird
# 4               CDM_photodraw_e21548096119835       012119_2  age8   rabbit
#
#   condition                 ref_image_name  stroke_count  \
# 0         P    images_photocues/bird_3.png             1
# 1         S     images_photocues/cat_3.png             1
# 2         S  images_photocues/rabbit_2.png             1
# 3         P    images_photocues/bird_1.png             1
# 4         S  images_photocues/rabbit_1.png             1
#
#                                                  svg location    group  bin  \
# 0  M381.71875,525.42188l2.64745,-29.2329l-3.00642...      CDM  animals  153
# 1  M113.71875,415.42188l-0.54331,23.5977l-1.45669...      CDM  animals  153
# 2  "M243.21875,306.42188l-2.65361,-13.19572l-0.78...      THU  animals  153
# 3  M145.71875,291.42188l4.14908,8.73997l5.95342,1...      CDM  animals  177
# 4  M481.71875,465.42188l5.5896,-14.05739l2.39503,...      CDM  animals  177
#
#    bin_9
# 0     51
# 1     51
# 2     51
# 3     59
# 4     59

# %%
## do we have the 9 items in each bin_9?
checker = []
for i, bins in regroup_df.groupby('bin_9'):
    c = bins['filename'].nunique()
    checker.append(c)

C = pd.DataFrame(checker, columns=['numSketch'])
print('There are {} items in each bin_9'.format(C['numSketch'].unique()))
# Out:
# There are [9] items in each bin_9

# %%
# reallyRun = True
# if reallyRun:    
#     ## check last bin to see if there's 8
#     # display(regroup_df.loc[regroup_df['bin_8'] == regroup_df['bin_8'].max()])
    
#     ## grab extra 4 drawings from prior bin
#     extra_4 = regroup_df.loc[regroup_df['bin_8'] == regroup_df['bin_8'].max() - 1].head(4)
    
#     ## add extra 4 to last bin 
#     extra_4['bin_8'] = regroup_df['bin_8'].max()
# #     display(extra_4)
#     regroup_df = regroup_df.append(extra_4)
    
#     ## visually check things
#     ## check last bin to see if there's 8
#     display(regroup_df.loc[regroup_df['bin_8'] == regroup_df['bin_8'].max()])
    
#     print('added 4 extra sketches to last bin')

# %%
print('How many bins are there now? {}'.format(regroup_df['bin_9'].nunique()))
# Out:
# How many bins are there now? 76

# %%
# from collections import Counter
# Counter(Counter(regroup_df.bin_9.value_counts().to_dict()))

# %% [markdown]
# ### now merge at stroke-level

# %%
## add bin col to sketch-level animal data
full_stroke_data = data_test.merge(regroup_df, left_on='filename', right_on='filename', suffixes=('', '_drop'))

# drop the duplicate columns
full_stroke_data.drop([col for col in full_stroke_data.columns if 'drop' in col], axis=1, inplace=True)

## col cleanup
# full_stroke_data['arcLength'] = full_stroke_data['arcLength'].astype('int32')
full_stroke_data['stroke_count'] = full_stroke_data['stroke_count'].astype('int32')
# full_stroke_data['currStrokeNum'] = full_stroke_data['currStrokeNum'].astype('int32')

# %%
## did we retain all our sketches? 
assert full_stroke_data['filename'].nunique() == G['filename'].nunique()

# %%
## visually check that things make sense — this should show all sketches at the stroke-level of first bin
d = full_stroke_data.loc[full_stroke_data['bin'] == 0]
# for i, group in d.groupby('filename'):
#     display(group)

# %%
# final['arcLength'] = final['arcLength'].astype(str) 
# final['currStrokeNum'] = final['currStrokeNum'].astype(str) 
full_stroke_data['stroke_count'] = full_stroke_data['stroke_count'].astype(str) 
full_stroke_data['bin'] = full_stroke_data['bin'].astype(str) 
full_stroke_data['bin_9'] = full_stroke_data['bin_9'].astype(str) 

full_stroke_data = full_stroke_data.drop(columns=['Unnamed: 0'])

# %%
## copy over
final = full_stroke_data.copy()

# %%
final.head()
# Out:
#                       session_id     subID   age category condition  \
# 0  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
# 1  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
# 2  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
# 3  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
# 4  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
#
#                                             filename  \
# 0  /Users/brialong/Documents/GitHub/devphotodraw/...
# 1  /Users/brialong/Documents/GitHub/devphotodraw/...
# 2  /Users/brialong/Documents/GitHub/devphotodraw/...
# 3  /Users/brialong/Documents/GitHub/devphotodraw/...
# 4  /Users/brialong/Documents/GitHub/devphotodraw/...
#
#                   ref_image_name stroke_count  \
# 0  images_photocues/rabbit_1.png            1
# 1  images_photocues/rabbit_1.png            2
# 2  images_photocues/rabbit_1.png            3
# 3  images_photocues/rabbit_1.png            4
# 4  images_photocues/rabbit_1.png            5
#
#                                                  svg location    group  bin  \
# 0  M634.71875,474.42188l-21.35678,12.64963l-22.64...      CDM  animals  145
# 1  M590.71875,446.42188l-9.94288,-2.39073l-10.581...      CDM  animals  145
# 2  M601.71875,339.42188l-8.21063,-3.25486l-8.9780...      CDM  animals  145
# 3  M257.71875,502.42188l-15.71523,3.61524l-15.153...      CDM  animals  145
# 4  M266.71875,577.42188l-13.02625,8.48312l-16.265...      CDM  animals  145
#
#   bin_9
# 0    48
# 1    48
# 2    48
# 3    48
# 4    48

# %% [markdown]
# ## add in ROIs data

# %%
import devphotodraw_labels as rois
importlib.reload(rois)
from devphotodraw_labels import ROIS

## convert ROI dictionary into ROI dataframe
R = pd.DataFrame(ROIS)

## add color for buttonGallery
R['color'] = '#fed541'

## convert so that can be JSON serialized later
R['part_num'] = R['part_num'].astype(str)

# %%
##IMPORTANT! Name dataframe according to group type
if whichGroup['group'].unique() == 'animals':
    R_subset = R.loc[R['object'].isin(['rabbit', 'cat', 'bird'])]
elif whichGroup['group'].unique() == 'small_objects':
    R_subset = R.loc[R['object'].isin(['watch', 'cup', 'hat'])]
elif whichGroup['group'].unique() == 'big_objects':
    R_subset = R.loc[R['object'].isin(['chair', 'tree', 'house'])]
elif whichGroup['group'].unique() == 'vehicles':
    R_subset = R.loc[R['object'].isin(['bike', 'car', 'airplane'])]

# %%
R_subset.head()
# Out:
#    object label_name part_num    color
# 12    cat       Tail        1  #fed541
# 13    cat        Eye        2  #fed541
# 14    cat        Ear        3  #fed541
# 15    cat        Leg        4  #fed541
# 16    cat    Whisker        5  #fed541

# %% [markdown]
# ### generate meta to insert into mongoDB

# %%
#initalize list of all version dictionaries
Meta = [] 

printed=False
for name, group in final.groupby(['bin_9']):  
    display(group)
    print('Adding {} to Meta'.format(name)) 
    clear_output(wait=True)
    Batch = {} # initialize batch-level dictionary 
    Trials = [] # list of sketches, each list containing sublist of strokes & ROI information
    
    for n,g in group.groupby('filename'): # looping over sketches within a batch
        rois = R_subset[R_subset['object']==g.category.unique()[0]].to_dict(orient='records')
        strokes = g.to_dict(orient='records')
        Trials.append({'strokes': strokes, 'rois': rois}) # append list of strokes and rois to trial list
    Batch['meta'] = Trials # attaching trial list to batch metadata
    Batch['batch_id'] = np.unique(group['bin_9'].values)[0]  
    Batch['games'] = []
    Meta.append(Batch)
    
print('Done!')
# Out:
# Done!

# %%
## check how many Meta are being inserted
len(Meta)
# Out:
# 76

# %%
## does this match the number of bins that were made?
assert len(Meta) == full_stroke_data['bin_9'].nunique()*final['group'].nunique()

# %%
# if full dataset PER group
dataset_name = 'devphotodraw_{}'.format(whichGroup['group'][0])
print('Saving out json dictionary out to file...') 
with open('{}_meta.js'.format(dataset_name), 'w') as fout:
    json.dump(Meta, fout)
print('Done!')
# Out:
# Saving out json dictionary out to file...
# Done!

# %%
#reload JSON back in to the new stimulus collection
J = json.loads(open('{}_meta.js'.format(dataset_name),mode='r').read())
print('dataset_name: {}'.format(dataset_name))
print('Length of J is: {}'.format(len(J)))
# Out:
# dataset_name: devphotodraw_animals
# Length of J is: 76

# %% [markdown]
# ### insert records into mongoDB
# Insert records into mongodb
#
# Run this in terminal: ssh -fNL 27017:127.0.0.1:27017 hhuey@cogtoolslab.org

# %%
## remember to establish tunnel to mongodb on remote server first
#### e.g. by running at the terminal, `ssh -fNL 27017:127.0.0.1:27017 USERNAME@cogtoolslab.org`

# set vars 
auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'cogtoolslab.org' ## cogtoolslab ip address

# have to fix this to be able to analyze from local
conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
db = conn['stimuli']
coll = db[dataset_name]

# %%
## now really insert data
reallyRun = True
if reallyRun:
    for (i,j) in enumerate(J):
        print ('%d of %d uploaded ...' % (i+1,len(J)))
        clear_output(wait=True)
        coll.insert_one(j)
print('Done!')
# Out:
# Done!

# %%
## check how many records were inserted
coll.estimated_document_count()
# Out:
# 76

# %%
## inspect one of these annotation sessions
coll.find_one()
# Out:
# {'_id': ObjectId('628c2e31d5b8e10848929561'),
#  'meta': [{'strokes': [{'session_id': 'CDM_photodraw_e21547240775263',
#      'subID': '011119_7',
#      'age': 'age6',
#      'category': 'bird',
#      'condition': 'P',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/P_bird_sketch_age6_CDM_photodraw_e21547240775263.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '1',
#      'svg': 'M263.71875,297.42188l-10.26556,-1.55833l-9.7741,0.53426l-19.96034,2.02407l-15,2l-11,4l-7.02413,2.01064l-9.10835,2.37378l-8.79211,2.43157l-6.07541,2.18401l-4.46207,2.52287l-1.66116,1.99206l0.12323,2.48507l3.23972,2.95868l5.93161,3.74527l6.34594,3.6433l4.48273,2.65275l28.07682,16.58636l29.92318,11.41364l7.68726,2.94969l8.98044,4.8124l8.39659,5.43135l5.9357,4.80656l2.75147,1.87733l3.24853,1.12267v-4',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547240775263',
#      'subID': '011119_7',
#      'age': 'age6',
#      'category': 'bird',
#      'condition': 'P',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/P_bird_sketch_age6_CDM_photodraw_e21547240775263.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '2',
#      'svg': 'M268.71875,297.42188l1.01294,-5.818l2.78142,-4.815l9.32392,-7.30242l22.88173,-10.06458l17.97932,-8.24954l20.27482,-7.19555l20.89775,-4.223l19.84812,0.66809l10.56814,5.56458l8.43186,8.43542l8.06335,9.18834l5.93665,10.81166l1.25158,12.02614l-3.66921,10.11137l-13.58236,17.86249l-14.54154,14.80413l-17.16475,11.35645l-36.2937,17.83943l-8.15181,2.53368l-9.24437,0.80181l-18.60382,-0.33549l-9.37281,0.33216l-4.64199,-0.52098l-1.9852,-1.81117l1,-1',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547240775263',
#      'subID': '011119_7',
#      'age': 'age6',
#      'category': 'bird',
#      'condition': 'P',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/P_bird_sketch_age6_CDM_photodraw_e21547240775263.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '3',
#      'svg': 'M347.71875,303.42188l1.54097,-5.35895l0.45903,-4.64105l-0.06849,-6.50999l-1.03082,-3.61l-3.23116,-1.55001l-6.66952,-0.33h-10l-3.12747,2.75013l-2.50877,4.84898l-3.36376,9.40089l-0.80504,2.55338l-1.07237,4.33225l-0.63367,4.38943l0.51108,2.72494l6.75349,3.01959l6.6197,-2.4368l5.68311,-5.47819l3.9437,-6.10459l2.1087,-5.25931l0.60909,-3.31716l-0.71778,-2.42353l-3.32537,-1.90849l-3.08298,0.50086l-4.0948,5.57307l0.90677,7.24035l3.16899,2.58496l5.42739,1.00925',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547240775263',
#      'subID': '011119_7',
#      'age': 'age6',
#      'category': 'bird',
#      'condition': 'P',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/P_bird_sketch_age6_CDM_photodraw_e21547240775263.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '4',
#      'svg': 'M376.71875,348.42188l-16.91453,-4.05158l-14.74372,1.59421l-12.43838,6.31734l-9.99851,10.11779l-7.42412,12.99557l-4.7152,14.95068l-1.87176,15.98312l1.10621,16.09288l3.57971,13.16663l5.93332,12.09316l7.92017,10.96119l9.54026,9.77073l22.4737,15.73606l24.55285,10.27223l38.41784,9.22138l18.66198,2.03574l18.13334,-0.3371l17.4817,-3.2021l16.70704,-6

#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21544206692186',
#      'subID': '120718_1',
#      'age': 'age5',
#      'category': 'rabbit',
#      'condition': 'S',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/rabbit/S_rabbit_sketch_age5_CDM_photodraw_e21544206692186.png',
#      'ref_image_name': 'images_photocues/rabbit_1.png',
#      'stroke_count': '6',
#      'svg': 'M392.71875,343.42188l-1.12226,-6.51561l-2.07038,-7.02573l-4.22406,-4.50506l-3.2964,-0.36016l-4.2869,1.40655l-1.99686,1.83771l-0.06904,2.22903l3.85939,4.58496l6.21264,3.00911l4.99386,-0.66081l0.35468,-2.48635l0.14911,-4.95189l-0.10279,-4.98277l-0.40101,-2.579l-4.16707,-0.38687l-2.83293,2.38687',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'}],
#    'rois': [{'object': 'rabbit',
#      'label_name': 'Ear',
#      'part_num': '1',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Nose',
#      'part_num': '2',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Eye',
#      'part_num': '3',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Head',
#      'part_num': '4',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Body',
#      'part_num': '5',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Tail',
#      'part_num': '6',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Mouth',
#      'part_num': '7',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Leg',
#      'part_num': '8',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Foot',
#      'part_num': '9',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Tooth/teeth',
#      'part_num': '10',
#      'color': '#fed541'},
#     {'object': 'rabbit',
#      'label_name': 'Whisker',
#      'part_num': '11',
#      'color': '#fed541'}]},
#   {'strokes': [{'session_id': 'Tsinghua_photodraw_production1578553081396',
#      'subID': 'iPad 3_THU8M1',
#      'age': 8.55,
#      'category': 'bird',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/bird_sketch_iPad 3_THU8M1_S.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '1',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M264.21875,194.42188l33.02086,-18.2152l17.16429,-8.54709l18.81485,-5.23772l11.69588,0.16947l10.31439,3.26036l19.98973,10.57017l12.59194,7.4211l10.70642,8.6067l8.87231,9.63514l7.08961,10.50641l9.03679,22.99802l2.52297,24.59722l-3.57953,24.93914l-9.27073,24.0238l-14.5506,21.85118l-19.41917,18.42129l-9.19539,7.06994l-9.80461,5.93006l-9.46914,2.79589l-9.7046,1.07907l-19.82626,1.12503l-17.83119,1.43288l-15.03148,-1.79152l-12.85015,-6.8622l-5.80032,-5.90957l-5.48688,-7.86959l-5.46398,-12.65078l-2.617,-12.93522l-3.91902,-26.414l-0.54418,-4.28843l-0.40122,-7.29584l-0.34853,-19.64857l0.29844,-19.78215l0.40748,-7.46282l0.58801,-4.52219l6.58452,-16.70568l3.10342,-8.39715l1.31205,-8.89717" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
# ...
#      'part_num': '5',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Tail',
#      'part_num': '6',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Beak/mouth',
#      'part_num': '7',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Leg',
#      'part_num': '8',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Foot',
#      'part_num': '9',
#      'color': '#fed541'}]},
#   {'strokes': [{'session_id': 'Tsinghua_photodraw_production1577086735995',
#      'subID': 'iPad 2_THU6M4',
#      'age': 7.15,
#      'category': 'cat',
#      'condition': 'P',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 2_THU6M4_P.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '1',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="

#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M277.21875,301.42188l13,4l0.13675,1.47734l-0.35446,3.0203l-0.4956,3.02148l-0.28669,1.48087l-5.03183,14.44179l-3.28775,7.25027l-3.68042,5.30794" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1577086735995',
#      'subID': 'iPad 2_THU6M4',
#      'age': 7.15,
#      'category': 'cat',
#      'condition': 'P',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 2_THU6M4_P.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '8',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M292.21875,311.42188l3.8842,4.96438l-0.54679,6.55541l-1.46549,6.54551l1.12809,4.9347l3.94446,0.34648l7.04146,-1.12183l7.2985,-1.48416l4.71558,-0.74049h1l0.24547,-2.85168l-1.24547,-2.14832" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1577086735995',
#      'subID': 'iPad 2_THU6M4',
#      'age': 7.15,
#      'category': 'cat',
#      'condition': 'P',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 2_THU6M4_P.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '9',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M243.21875,295.42188l-12.09919,-7.94544l-12.90081,-8.05456l-34,-34l-21.38853,-15.02667l-22.61147,-12.97333" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1577086735995',
#      'subID': 'iPad 2_THU6M4',
#      'age': 7.15,
#      'category': 'cat',
#      'condition': 'P',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 2_THU6M4_P.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '10',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M258.21875,294.42188l-25.19093,7.02207l-25.14831,9.18614l-24.72869,8.58203l-23.93207,5.20976l-11.9712,2.84129l-12.0288,2.15871" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1577086735995',
#      'subID': 'iPad 2_THU6M4',
#      'age': 7.15,
#      'category': 'cat',
#      'condition': 'P',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 2_THU6M4_P.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '11',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M272.21875,311.42188l-6.39215,11.7992l-8.02015,11.2429l-16.5877,21.95791l-27.02577,43.98654l-14.49956,21.61782l-16.47468,19.39564" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1577086735995',
#      'subID': 'iPad 2_THU6M4',
#      'age': 7.15,
#      'category': 'cat',
#      'condition': 'P',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 2_THU6M4_P.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '12',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M335.21875,273.42188l29,-9l10.24391,-4.14683l9.9926,-5.87645l18.76349,-12.97672l12,-9l4.03622,-2.59632l2.96378,-2.40368l-3.28972,0.97885l-5.51864,4.01231l-5.36446,4.51673l-2.82717,2.49212" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1577086735995',
#      'subID': 'iPad 2_THU6M4',
#      'age': 7.15,
#      'category': 'cat',
#      'condition': 'P',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 2_THU6M4_P.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '13',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M353.21875,276.42188l26.20463,0.08493l25.79537,-3.08493l12.67907,-1.80333l12.32093,-2.19667l2.14739,-0.66371l-0.28967,0.21114l-3.85772,1.45257" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1577086735995',
#      'subID': 'iPad 2_THU6M4',
#      'age': 7.15,
#      'category': 'cat',
#      'condition': 'P',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 2_THU6M4_P.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '14',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M347.21875,282.42188l6.83437,-0.22247l3.09346,0.43143l2.07217,1.79104l2.67388,10.37556l2.32612,10.62444l4.50221,7.7402l6.52858,8.67091l6.26319,8.21536l3.70602,6.37354l3,9l2.18303,3.19066l3.91117,4.57494l10.51731,9.99664l5.36143,3.76866l4.60013,1.84686l3.21647,-0.90146l1.21046,-4.4763" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '2',
#      'bin_9': '0'}],
#    'rois': [{'object': 'cat',
#      'label_name': 'Tail',
#      'part_num': '1',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Eye',
#      'part_num': '2',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Ear',
#      'part_num': '3',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Leg',
#      'part_num': '4',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Whisker',
#      'part_num': '5',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Head',
#      'part_num': '6',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Mouth',
#      'part_num': '7',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Nose',
#      'part_num': '8',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Body',
#      'part_num': '9',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Paw',
#      'part_num': '10',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Fur',
#      'part_num': '11',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Claw',
#      'part_num': '12',
#      'color': '#fed541'}]}],
#  'batch_id': '0',
#  'games': []}

# %%
# db.drop_collection('devphotodraw_animals')
# Out:
# {'ns': 'stimuli.devphotodraw_animals', 'nIndexesWas': 1, 'ok': 1.0}
