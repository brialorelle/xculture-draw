# %%
import os, sys

import pymongo as pm
import numpy as np
import scipy.stats as stats
import pandas as pd
import json
import re

import matplotlib
from matplotlib import pylab, mlab, pyplot
# %matplotlib inline
from IPython.core.pylabtools import figsize, getfigs
plt = pyplot
import seaborn as sns
sns.set_context('talk')
sns.set_style('white')

from IPython.display import clear_output
import importlib

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)
warnings.filterwarnings("ignore", message="numpy.dtype size changed")
warnings.filterwarnings("ignore", message="numpy.ufunc size changed")
pd.options.mode.chained_assignment = None

# %%
# directory & file hierarchy
proj_dir = os.path.abspath('..')
stim_dir = os.path.join(proj_dir,'stimuli')

# %% [markdown]
# ## load in data
# CDM = Children’s Discovery Museum, San Jose <br>
# THU = Tsinghua University, Beijing

# %%
CDM = pd.read_csv(os.path.join(stim_dir, 'CDM_photodraw_e2_svg_output2022.csv'))
THU = pd.read_csv(os.path.join(stim_dir, 'THU_photodraw_e2_svg_output2022.csv'))
data = CDM.append(THU)

# %%
data.head()
# Out:
#    Unnamed: 0                     session_id     subID   age     category  \
# 0           0  CDM_photodraw_e21540576831945  102618_1  age4  this square
# 1           1  CDM_photodraw_e21540576907849  102618_1  age4  this square
# 2           2  CDM_photodraw_e21540576907849  102618_1  age4   this shape
# 3           3  CDM_photodraw_e21540576907849  102618_1  age4   this shape
# 4           4  CDM_photodraw_e21540576907849  102618_1  age4    rectangle
#
#   condition                                           filename  \
# 0         S  /Users/brialong/Documents/GitHub/devphotodraw/...
# 1         S  /Users/brialong/Documents/GitHub/devphotodraw/...
# 2         S  /Users/brialong/Documents/GitHub/devphotodraw/...
# 3         S  /Users/brialong/Documents/GitHub/devphotodraw/...
# 4         P  /Users/brialong/Documents/GitHub/devphotodraw/...
#
#                    ref_image_name  stroke_count  \
# 0               images/square.png             1
# 1               images/square.png             1
# 2                images/shape.png             1
# 3                images/shape.png             2
# 4  images_photocues/rectangle.png             1
#
#                                                  svg
# 0  M224.71875,503.42188l-8.04107,2.01575l-3.82151...
# 1  M224.71875,503.42188l-8.04107,2.01575l-3.82151...
# 2  M397.71875,396.42188l4,8l1.73384,0.05863l3.071...
# 3  M397.71875,396.42188l4,8l1.73384,0.05863l15.26...
# 4  M18.71875,1.42188l-15.07726,15.62757l-6.53569,...

# %%
## preprocessing
## only grab object category data (not tracing or familiarization data)
data_test = data.loc[data['category'].isin(['watch', 'bike', 'chair', 'car', 'tree', 'rabbit', 
                                            'house', 'cup', 'hat', 'cat', 'bird', 'airplane'])]

data_test['location'] = data_test['session_id'].apply(lambda x:x.split('_')[0])
data_test['location'] = data_test['location'].replace('Tsinghua', 'THU')

# %%
## how many sketches in each dataset?
print('{} CDM sketches and {} THU sketches'.format(data_test.loc[data_test['location'] == 'CDM']['filename'].nunique(), 
                                                   data_test.loc[data_test['location'] == 'THU']['filename'].nunique()))
print('{} total sketches'.format(data_test['filename'].nunique()))

assert data_test.loc[data_test['location'] == 'CDM']['filename'].nunique() + data_test.loc[data_test['location'] == 'THU']['filename'].nunique() == data_test['filename'].nunique()
# Out:
# 1438 CDM sketches and 1291 THU sketches
# 2729 total sketches

# %%
## first look at things at the sketch-level
df = data_test.groupby('filename').first().reset_index()

# %%
## how many of each category?
counts = df.groupby(['location'])['category'].value_counts()
display(counts)
# Out:
# location  category
# CDM       chair       121
#           cup         121
#           hat         121
#           bike        120
#           bird        120
#           house       120
#           tree        120
#           watch       120
#           car         119
#           cat         119
#           rabbit      119
#           airplane    118
# THU       bike        113
#           airplane    112
#           bird        110
#           cat         109
#           chair       109
#           tree        109
#           hat         108
#           house       107
#           rabbit      105
#           watch       104
#           cup         103
#           car         102
# Name: category, dtype: int64

# %%
## add groups based on 4 traits: animacy, size, familiarity, and artificiality
## The code for the selection can be found here:
# https://github.com/cogtoolslab/photodraw32/blob/master/stimuli/photodraw2x2_generate_stims/select_sketchy_classes_for_photodraw32.ipynb
# create a list of our conditions
conditions = [
    ((df['category'] == 'rabbit') | (df['category'] == 'cat') | (df['category'] == 'bird')), 
    ((df['category'] == 'watch') | (df['category'] == 'cup') | (df['category'] == 'hat')), 
    ((df['category'] == 'chair') | (df['category'] == 'tree') | (df['category'] == 'house')), 
    ((df['category'] == 'bike') | (df['category'] == 'car') | (df['category'] == 'airplane')), 
]

# create a list of the values we want to assign for each condition
values = [
    'animals', 
    'small_objects', 
    'big_objects', 
    'vehicles', 
]

# create a new column and use np.select to assign values to it using our lists as arguments
df['group'] = np.select(conditions, values)

# %%
## IMPORTANT
## which "group" are we generating metadata for?
whichGroup = df.loc[df['group'] == 'animals']
whichGroup = whichGroup.reset_index(drop=True)

## initialize empty dataframe to copy into
G = pd.DataFrame()

## copy data over
reallyRun = True
if reallyRun:
    G = whichGroup.copy()
    G = G.reset_index(drop=True)
print('Generating stims for {} dataset'.format(whichGroup['group'].unique()))
# Out:
# Generating stims for ['animals'] dataset

# %% [markdown]
# ### NOTE TO HOLLY: we also want to counterbalance by site?

# %%
## define array params
subgroups = G['category'].unique()
l = len(subgroups)
m = min((G.groupby(['category']).size()))

## generate empty array
arr = np.zeros((m, l))


# ## define array params
# subgroups = G['location'].unique()
# l = len(subgroups)
# m = min((G.groupby(['location']).size()))

# ## generate empty array
# arr = np.zeros((m, l))

# %%
# shuffle sketches and put into array
for i, subgroup in enumerate(subgroups):
    perm = np.random.permutation(G.index[G['category'] == subgroup])
    arr[:, i] = perm[:m]
    
# name generated bins
G["bin"] = 0

for i in range(m):
    G.loc[arr[i,:], "bin"] = i

# %%
print('How many bins were made? {}'.format(G['bin'].nunique()))
# Out:
# How many bins were made? 224

# %%
## how many sketches per bin?
checker = []
for i, bins in G.groupby('bin'):
    c = bins['filename'].nunique()
    checker.append(c)

C = pd.DataFrame(checker, columns=['numSketch'])
print('How many sketches are in each bin? {}'.format(C['numSketch'].unique()))
# Out:
# How many sketches are in each bin? [13  3]

# %% [markdown]
# ##### important! split bins if necessary - if not, skip

# %%
## visually check the first bin
print('There are {} extra sketches in this first bin, which need to be split out'.format(len(G.loc[G['bin'] == 0])))
G.loc[G['bin'] == 0].reset_index(drop=True)
# Out:
# There are 13 extra sketches in this first bin, which need to be split out
#                                              filename  Unnamed: 0  \
# 0   /Users/brialong/Documents/GitHub/devphotodraw/...        1507
# 1   /Users/brialong/Documents/GitHub/devphotodraw/...        3559
# 2   /Users/brialong/Documents/GitHub/devphotodraw/...        3915
# 3   /Users/brialong/Documents/GitHub/devphotodraw/...        7031
# 4   THU_sketches_and_metadata/bird_sketch_Ipad1-TH...        7543
# 5   THU_sketches_and_metadata/bird_sketch_Ipad4_TH...        1675
# 6   THU_sketches_and_metadata/bird_sketch_iPad1_TH...        9839
# 7   THU_sketches_and_metadata/bird_sketch_iPad_THU...       12523
# 8   THU_sketches_and_metadata/cat_sketch_Ipad1__TH...       11006
# 9   THU_sketches_and_metadata/cat_sketch_Ipad2_THU...        4991
# 10  THU_sketches_and_metadata/cat_sketch_iPad 3_TH...       10221
# 11  THU_sketches_and_metadata/cat_sketch_iPad1_THU...       11362
# 12  THU_sketches_and_metadata/rabbit_sketch_Ipad2_...        5497
#
#                                     session_id            subID    age  \
# 0                CDM_photodraw_e21542057631101         111218_6   age5
# 1                CDM_photodraw_e21547060282520         O10919_1   age4
# 2                CDM_photodraw_e21547069129052         010919_6   age7
# 3                CDM_photodraw_e21547849081297         011819_8   age6
# 4   Tsinghua_photodraw_production1576566518161    Ipad1-THU8M36   8.52
# 5   Tsinghua_photodraw_production1573784365523     Ipad4_THU4M7   4.10
# 6   Tsinghua_photodraw_production1573786980255     iPad1_THU4M9   4.96
# 7   Tsinghua_photodraw_production1575960999852     iPad_THU8M21   8.35
# 8   Tsinghua_photodraw_production1578968887739  Ipad1__THU 9M47   9.85
# 9   Tsinghua_photodraw_production1576134884446    Ipad2_THU6M30   6.57
# 10  Tsinghua_photodraw_production1578462794400    iPad 3_THU9F1   9.99
# 11  Tsinghua_photodraw_production1578969773820   iPad1_THU10F40  10.13
# 12  Tsinghua_photodraw_production1575529585327    Ipad2_THU6F19   6.51
#
#    category condition                 ref_image_name  stroke_count  \
# 0      bird         P    images_photocues/bird_2.png             1
# 1      bird         S    images_photocues/bird_1.png             1
# 2      bird         S    images_photocues/bird_3.png             1
# 3       cat         P     images_photocues/cat_2.png             1
# 4      bird         S    images_photocues/bird_3.png             1
# 5      bird         P    images_photocues/bird_3.png             1
# 6      bird         S    images_photocues/bird_3.png             1
# 7      bird         S    images_photocues/bird_2.png             1
# 8       cat         S     images_photocues/cat_1.png             1
# 9       cat         S     images_photocues/cat_2.png             1
# 10      cat         S     images_photocues/cat_1.png             1
# 11      cat         P     images_photocues/cat_2.png             1
# 12   rabbit         S  images_photocues/rabbit_2.png             1
#
#                                                   svg location    group  bin
# 0   M252.71875,392.42188l-3.26303,2.76387l-2.45018...      CDM  animals    0
# 1   M82.71875,671.42188l-4.633,-9.87144l-1.29078,-...      CDM  animals    0
# 2   M558.71875,213.42188l-22.55258,-6.3711l-23.447...      CDM  animals    0
# 3   M527.71875,424.42188l10,-7l1.529,-0.13259l3.57...      CDM  animals    0
# 4   <path xmlns="http://www.w3.org/2000/svg" d="M3...      THU  animals    0
# 5   <path xmlns="http://www.w3.org/2000/svg" d="M2...      THU  animals    0
# 6   <path xmlns="http://www.w3.org/2000/svg" d="M3...      THU  animals    0
# 7   <path xmlns="http://www.w3.org/2000/svg" d="M1...      THU  animals    0
# 8   <path xmlns="http://www.w3.org/2000/svg" d="M3...      THU  animals    0
# 9   <path xmlns="http://www.w3.org/2000/svg" d="M4...      THU  animals    0
# 10  <path xmlns="http://www.w3.org/2000/svg" d="M6...      THU  animals    0
# 11  <path xmlns="http://www.w3.org/2000/svg" d="M1...      THU  animals    0
# 12  <path xmlns="http://www.w3.org/2000/svg" d="M2...      THU  animals    0

# %%
import math 
num_divide_by = math.ceil(len(G.loc[G['bin'] == 0])/3)

# %%
## need to split the first bin that has too many sketches
need_split = G.loc[G['bin'] == 0]
need_split['filename'].nunique()
# Out:
# 13

# %%
## randomly shuffle and split into 4 new bins
shuffled = need_split.sample(frac=1)
result = np.array_split(shuffled, num_divide_by)

# %%
## subset each new bin
result_1 = result[0]
result_2 = result[1]
result_2['bin'] = G['bin'].max() + 1
result_3 = result[2]
result_3['bin'] = G['bin'].max() + 2
result_4 = result[3]
result_4['bin'] = G['bin'].max() + 3
result_5 = result[4]
result_5['bin'] = G['bin'].max() + 4
# result_6 = result[5]
# result_6['bin'] = G['bin'].max() + 5
# result_7 = result[6]
# result_7['bin'] = G['bin'].max() + 6
# result_8 = result[7]
# result_8['bin'] = G['bin'].max() + 7
# result_9 = result[8]
# result_9['bin'] = G['bin'].max() + 8

display(len(result_1))
display(len(result_2))
display(len(result_3))
display(len(result_4))
display(len(result_5))
# display(len(result_6))
# display(len(result_7))
# display(len(result_8))
# display(len(result_9))
# Out:
# 3
# 3
# 3
# 2
# 2

# %%
extra_result_1 = result_2.tail(1)
extra_result_2 = result_1.tail(1)

result_4 = result_4.append(extra_result_1)
result_4['bin'] = int(result_4.iloc[0]['bin'])

result_5 = result_5.append(extra_result_2)
result_5['bin'] = int(result_5.iloc[0]['bin'])

# %%
## remove first bin, so that we can replace it
G = G[G.bin != 0]

# add the new bins back into the dataframe
G = pd.concat([G, result_1, 
                  result_2, 
                  result_3, 
                  result_4, 
                  result_5]).reset_index(drop=True)

# %%
# visually check the first bin
G.loc[G['bin'] == 0].reset_index(drop=True)
# Out:
#                                             filename  Unnamed: 0  \
# 0  /Users/brialong/Documents/GitHub/devphotodraw/...        7031
# 1  THU_sketches_and_metadata/cat_sketch_iPad 3_TH...       10221
# 2  /Users/brialong/Documents/GitHub/devphotodraw/...        3915
#
#                                    session_id          subID   age category  \
# 0               CDM_photodraw_e21547849081297       011819_8  age6      cat
# 1  Tsinghua_photodraw_production1578462794400  iPad 3_THU9F1  9.99      cat
# 2               CDM_photodraw_e21547069129052       010919_6  age7     bird
#
#   condition               ref_image_name  stroke_count  \
# 0         P   images_photocues/cat_2.png             1
# 1         S   images_photocues/cat_1.png             1
# 2         S  images_photocues/bird_3.png             1
#
#                                                  svg location    group  bin
# 0  M527.71875,424.42188l10,-7l1.529,-0.13259l3.57...      CDM  animals    0
# 1  <path xmlns="http://www.w3.org/2000/svg" d="M6...      THU  animals    0
# 2  M558.71875,213.42188l-22.55258,-6.3711l-23.447...      CDM  animals    0

# %%
## do we have the 4 items in each bin?
checker = []
for i, bins in G.groupby('bin'):
    c = bins['filename'].nunique()
    checker.append(c)

C = pd.DataFrame(checker, columns=['numSketch'])

print('Second check passed! There are {} items in each bin'.format(C['numSketch'].unique()))
assert C['numSketch'].unique() == G["category"].nunique()
# Out:
# Second check passed! There are [3] items in each bin

# %%
## did we retain all our sketches? 
assert G['filename'].nunique() == whichGroup['filename'].nunique()
print('Check passed! There are {} sketches still in our binned dataset'.format(G['filename'].nunique()))
# Out:
# Check passed! There are 682 sketches still in our binned dataset

# %%
## currently there are 3 sketches in each bin
## now we want to group bins, so that there are 9 sketches in a 'bin_9'
numbers = list(range(0, G['bin'].max()+1))
numbers = pd.DataFrame(numbers, columns=['bin'])
numbers['bin_9'] = np.arange(len(numbers)) // 3

regroup_df = G.merge(numbers, left_on='bin', right_on='bin')

# %%
print('How many bins were made? {}'.format(regroup_df['bin_9'].nunique()))
# Out:
# How many bins were made? 76

# %%
## visually look at things
regroup_df.head()
# Out:
#                                             filename  Unnamed: 0  \
# 0  /Users/brialong/Documents/GitHub/devphotodraw/...         886
# 1  THU_sketches_and_metadata/cat_sketch_Ipad2_THU...        5456
# 2  THU_sketches_and_metadata/rabbit_sketch_iPad 5...         280
# 3  /Users/brialong/Documents/GitHub/devphotodraw/...        4008
# 4  THU_sketches_and_metadata/cat_sketch_Ipad1_THU...        9198
#
#                                    session_id          subID   age category  \
# 0               CDM_photodraw_e21541799408496       110918_1  age4     bird
# 1  Tsinghua_photodraw_production1575529585327  Ipad2_THU6F19  6.51      cat
# 2  Tsinghua_photodraw_production1573786717640  iPad 5_THU5M9  5.02   rabbit
# 3               CDM_photodraw_e21547070395780       010919_7  age4     bird
# 4  Tsinghua_photodraw_production1576738027913  Ipad1_THU6F43  6.65      cat
#
#   condition                 ref_image_name  stroke_count  \
# 0         P    images_photocues/bird_3.png             1
# 1         P     images_photocues/cat_2.png             1
# 2         P  images_photocues/rabbit_3.png             1
# 3         P    images_photocues/bird_1.png             1
# 4         P     images_photocues/cat_3.png             1
#
#                                                  svg location    group  bin  \
# 0  M381.71875,525.42188l2.64745,-29.2329l-3.00642...      CDM  animals   85
# 1  <path xmlns="http://www.w3.org/2000/svg" d="M1...      THU  animals   85
# 2  <path xmlns="http://www.w3.org/2000/svg" d="M1...      THU  animals   85
# 3  M145.71875,291.42188l4.14908,8.73997l5.95342,1...      CDM  animals   61
# 4  <path xmlns="http://www.w3.org/2000/svg" d="M1...      THU  animals   61
#
#    bin_9
# 0     28
# 1     28
# 2     28
# 3     20
# 4     20

# %%
## do we have the 9 items in each bin_9?
checker = []
for i, bins in regroup_df.groupby('bin_9'):
    c = bins['filename'].nunique()
    checker.append(c)

C = pd.DataFrame(checker, columns=['numSketch'])
print('There are {} items in each bin_9'.format(C['numSketch'].unique()))
# Out:
# There are [9] items in each bin_9

# %%
# reallyRun = True
# if reallyRun:    
#     ## check last bin to see if there's 8
#     # display(regroup_df.loc[regroup_df['bin_8'] == regroup_df['bin_8'].max()])
    
#     ## grab extra 4 drawings from prior bin
#     extra_4 = regroup_df.loc[regroup_df['bin_8'] == regroup_df['bin_8'].max() - 1].head(4)
    
#     ## add extra 4 to last bin 
#     extra_4['bin_8'] = regroup_df['bin_8'].max()
# #     display(extra_4)
#     regroup_df = regroup_df.append(extra_4)
    
#     ## visually check things
#     ## check last bin to see if there's 8
#     display(regroup_df.loc[regroup_df['bin_8'] == regroup_df['bin_8'].max()])
    
#     print('added 4 extra sketches to last bin')

# %%
print('How many bins are there now? {}'.format(regroup_df['bin_9'].nunique()))
# Out:
# How many bins are there now? 76

# %%
# from collections import Counter
# Counter(Counter(regroup_df.bin_9.value_counts().to_dict()))

# %% [markdown]
# ### now merge at stroke-level

# %%
## add bin col to sketch-level animal data
full_stroke_data = data_test.merge(regroup_df, left_on='filename', right_on='filename', suffixes=('', '_drop'))

# drop the duplicate columns
full_stroke_data.drop([col for col in full_stroke_data.columns if 'drop' in col], axis=1, inplace=True)

## col cleanup
# full_stroke_data['arcLength'] = full_stroke_data['arcLength'].astype('int32')
full_stroke_data['stroke_count'] = full_stroke_data['stroke_count'].astype('int32')
# full_stroke_data['currStrokeNum'] = full_stroke_data['currStrokeNum'].astype('int32')

# %%
## did we retain all our sketches? 
assert full_stroke_data['filename'].nunique() == G['filename'].nunique()

# %%
## visually check that things make sense — this should show all sketches at the stroke-level of first bin
d = full_stroke_data.loc[full_stroke_data['bin'] == 0]
# for i, group in d.groupby('filename'):
#     display(group)

# %%
# final['arcLength'] = final['arcLength'].astype(str) 
# final['currStrokeNum'] = final['currStrokeNum'].astype(str) 
full_stroke_data['stroke_count'] = full_stroke_data['stroke_count'].astype(str) 
full_stroke_data['bin'] = full_stroke_data['bin'].astype(str) 
full_stroke_data['bin_9'] = full_stroke_data['bin_9'].astype(str) 

full_stroke_data = full_stroke_data.drop(columns=['Unnamed: 0'])

# %%
## copy over
final = full_stroke_data.copy()

# %%
final.head()
# Out:
#                       session_id     subID   age category condition  \
# 0  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
# 1  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
# 2  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
# 3  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
# 4  CDM_photodraw_e21540576907849  102618_1  age4   rabbit         P
#
#                                             filename  \
# 0  /Users/brialong/Documents/GitHub/devphotodraw/...
# 1  /Users/brialong/Documents/GitHub/devphotodraw/...
# 2  /Users/brialong/Documents/GitHub/devphotodraw/...
# 3  /Users/brialong/Documents/GitHub/devphotodraw/...
# 4  /Users/brialong/Documents/GitHub/devphotodraw/...
#
#                   ref_image_name stroke_count  \
# 0  images_photocues/rabbit_1.png            1
# 1  images_photocues/rabbit_1.png            2
# 2  images_photocues/rabbit_1.png            3
# 3  images_photocues/rabbit_1.png            4
# 4  images_photocues/rabbit_1.png            5
#
#                                                  svg location    group bin  \
# 0  M634.71875,474.42188l-21.35678,12.64963l-22.64...      CDM  animals  47
# 1  M590.71875,446.42188l-9.94288,-2.39073l-10.581...      CDM  animals  47
# 2  M601.71875,339.42188l-8.21063,-3.25486l-8.9780...      CDM  animals  47
# 3  M257.71875,502.42188l-15.71523,3.61524l-15.153...      CDM  animals  47
# 4  M266.71875,577.42188l-13.02625,8.48312l-16.265...      CDM  animals  47
#
#   bin_9
# 0    15
# 1    15
# 2    15
# 3    15
# 4    15

# %% [markdown]
# ## add in ROIs data

# %%
import devphotodraw_labels as rois
importlib.reload(rois)
from devphotodraw_labels import ROIS

## convert ROI dictionary into ROI dataframe
R = pd.DataFrame(ROIS)

## add color for buttonGallery
R['color'] = '#fed541'

## convert so that can be JSON serialized later
R['part_num'] = R['part_num'].astype(str)

# %%
##IMPORTANT! Name dataframe according to group type
if whichGroup['group'].unique() == 'animals':
    R_subset = R.loc[R['object'].isin(['rabbit', 'cat', 'bird'])]
elif whichGroup['group'].unique() == 'small_objects':
    R_subset = R.loc[R['object'].isin(['watch', 'cup', 'hat'])]
elif whichGroup['group'].unique() == 'big_objects':
    R_subset = R.loc[R['object'].isin(['chair', 'tree', 'house'])]
elif whichGroup['group'].unique() == 'vehicles':
    R_subset = R.loc[R['object'].isin(['bike', 'car', 'airplane'])]

# %%
R_subset.head()
# Out:
#    object label_name part_num    color
# 12    cat       Tail        1  #fed541
# 13    cat        Eye        2  #fed541
# 14    cat        Ear        3  #fed541
# 15    cat        Leg        4  #fed541
# 16    cat    Whisker        5  #fed541

# %% [markdown]
# ### generate meta to insert into mongoDB

# %%
#initalize list of all version dictionaries
Meta = [] 

printed=False
for name, group in final.groupby(['bin']):  
    display(group)
    print('Adding {} to Meta'.format(name)) 
    clear_output(wait=True)
    Batch = {} # initialize batch-level dictionary 
    Trials = [] # list of sketches, each list containing sublist of strokes & ROI information
    
    for n,g in group.groupby('filename'): # looping over sketches within a batch
        rois = R_subset[R_subset['object']==g.category.unique()[0]].to_dict(orient='records')
        strokes = g.to_dict(orient='records')
        Trials.append({'strokes': strokes, 'rois': rois}) # append list of strokes and rois to trial list
    Batch['meta'] = Trials # attaching trial list to batch metadata
    Batch['batch_id'] = np.unique(group['bin'].values)[0]  
    Batch['games'] = []
    Meta.append(Batch)
    
print('Done!')
# Out:
# Done!

# %%
## check how many Meta are being inserted
len(Meta)
# Out:
# 228

# %%
## does this match the number of bins that were made?
assert len(Meta) == full_stroke_data['bin'].nunique()*final['group'].nunique()

# %%
# if full dataset PER group
dataset_name = 'devphotodraw_{}'.format(whichGroup['group'][0])
print('Saving out json dictionary out to file...') 
with open('{}_meta.js'.format(dataset_name), 'w') as fout:
    json.dump(Meta, fout)
print('Done!')
# Out:
# Saving out json dictionary out to file...
# Done!

# %%
#reload JSON back in to the new stimulus collection
J = json.loads(open('{}_meta.js'.format(dataset_name),mode='r').read())
print('dataset_name: {}'.format(dataset_name))
print('Length of J is: {}'.format(len(J)))
# Out:
# dataset_name: devphotodraw_animals
# Length of J is: 228

# %% [markdown]
# ### insert records into mongoDB
# Insert records into mongodb
#
# Run this in terminal: ssh -fNL 27017:127.0.0.1:27017 hhuey@cogtoolslab.org

# %%
## remember to establish tunnel to mongodb on remote server first
#### e.g. by running at the terminal, `ssh -fNL 27017:127.0.0.1:27017 USERNAME@cogtoolslab.org`

# set vars 
auth = pd.read_csv('auth.txt', header = None) # this auth.txt file contains the password for the sketchloop user
pswd = auth.values[0][0]
user = 'sketchloop'
host = 'cogtoolslab.org' ## cogtoolslab ip address

# have to fix this to be able to analyze from local
conn = pm.MongoClient('mongodb://sketchloop:' + pswd + '@127.0.0.1')
db = conn['stimuli']
coll = db[dataset_name]

# %%
## now really insert data
reallyRun = True
if reallyRun:
    for (i,j) in enumerate(J):
        print ('%d of %d uploaded ...' % (i+1,len(J)))
        clear_output(wait=True)
        coll.insert_one(j)
print('Done!')
# Out:
# Done!

# %%
## check how many records were inserted
coll.estimated_document_count()
# Out:
# 228

# %%
## inspect one of these annotation sessions
coll.find_one()
# Out:
# {'_id': ObjectId('628c095c367586207ee0d170'),
#  'meta': [{'strokes': [{'session_id': 'CDM_photodraw_e21547069129052',
#      'subID': '010919_6',
#      'age': 'age7',
#      'category': 'bird',
#      'condition': 'S',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/S_bird_sketch_age7_CDM_photodraw_e21547069129052.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '1',
#      'svg': 'M558.71875,213.42188l-22.55258,-6.3711l-23.44742,-2.6289l-26.30556,-2.17137l-27.71027,-0.51601l-27.20235,3.32768l-12.81301,3.78907l-11.9688,5.57062l-21.90317,13.84823l-20.48225,15.66247l-19.03954,17.40712l-17.57504,19.08218l-7.79402,9.82071l-8.53167,12.1388l-15.91867,28.62672l-5.70822,15.18534l-3.08828,14.89827l0.37106,13.95991l4.66979,12.37025l7.731,9.22578l9.87828,7.12383l11.49035,5.29061l12.56721,3.7261l26.22414,3.83355l24.10903,0.80013h47l25.65872,-3.5479l26.24444,-6.75072l25.54286,-9.10141l23.55397,-10.59997l20.6278,-10.48317l20.53883,-12.38487l17.95552,-15.45085l7.22953,-9.239l5.64832,-10.4421l4.5286,-14.08134l1.11338,-12.5084l-1.72331,-11.33531l-3.98148,-10.56207l-12.42338,-20.40382l-14.51381,-22.10906l-6.76484,-11.74803l-8.1343,-12.24408l-9.93473,-10.24802l-12.16613,-5.75987',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547069129052',
#      'subID': '010919_6',
#      'age': 'age7',
#      'category': 'bird',
#      'condition': 'S',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/S_bird_sketch_age7_CDM_photodraw_e21547069129052.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '2',
#      'svg': 'M399.71875,273.42188l3.28812,-9.26949l4.20939,-7.63672l6.46063,-5.18361l10.04186,-1.91017l5.31602,-0.29108l4.68398,1.29108l1.58886,8.23049l-1.89359,8.11328l0.00877,6.19139l2.40053,1.81103l4.89542,0.65381h6l10.72863,-3.006l10.49051,-4.79213l19.78086,-11.20188l2.59767,-1.42058l4.78142,-2.34095l4.84188,-1.71019l2.77904,0.47172l-0.38753,1.97437l-2.06006,3.21779l-7.21407,8.55077l-8.13324,8.67931l-5.20509,5.57776l-1.06951,1.81256l-1.62029,3.44293l-1.02539,3.56519l0.71519,2.17932l6.31878,2.05448l5.89085,-0.09062l10.67162,-4.85747l18.11875,-16.10639l2.57623,-2.54581l4.2596,-4.19906l4.34168,-3.57662l2.82248,-0.67851l1.30512,5.65215l-0.30512,6.34785l-0.99451,15.23809l-4.00549,14.76191l-5.19262,8.82663l-2.66086,4.58592l-1.14652,3.58745',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547069129052',
#      'subID': '010919_6',
#      'age': 'age7',
#      'category': 'bird',
#      'condition': 'S',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/S_bird_sketch_age7_CDM_photodraw_e21547069129052.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '3',
#      'svg': 'M328.71875,276.42188l2.44249,-14.78026l-0.44249,-15.21974l-4.40479,-4.54254l-5.59521,-3.45746l-18.64949,-9.69792l-20.35051,-5.30208l-18.76365,-1.34171l-21.93768,1.22535l-23.1656,4.03984l-22.44741,7.10175l-19.78312,10.4111l-15.17272,13.96787l-5.2493,8.39505l-3.36691,9.37703l-1.24126,10.38994l1.12765,11.43378l2.97823,7.79748l5.11349,7.82802l11.90829,13.3745l19.30249,16.14717l20.78524,10.3597l22.74137,3.60626l12.25217,-1.03127l12.91873,-3.08187l24.52373,-9.16168l11.24437,-6.40815l10.2319,-8.43017l6.29703,-8.93463l4.25932,-11.44171l3.88263,-27.49929l0.16314,-28.81147l-0.39004,-13.08194l-0.21208,-11.23095',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547069129052',
#      'subID': '010919_6',
#      'age': 'age7',
#      'category': 'bird',
#      'condition': 'S',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/S_bird_sketch_age7_CDM_photodraw_e21547069129052.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '4',
#      'svg': 'M253.71875,265.42188l-13.50568,3.58536l-15.86119,3.59284l-15.42775,4.25374l-12.20538,5.56806l-5.04104,5.65438l-1.01618,6.52803l2.51243,6.18683l5.54479,4.63076l12.4737,3.27839l15.48097,0.39305l15.50363,-1.69267l12.54169,-2.97877',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547069129052',
#      'subID': '010919_6',
#      'age': 'age7',
#      'category': 'bird',
#      'condition': 'S',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/S_bird_sketch_age7_CDM_photodraw_e21547069129052.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '5',
#      'svg': 'M230.71875,246.42188l1,-13l2.03865,-0.9195l2.96135,-0.0805l3,-2h2l-5.21963,0.42496l-4.78037,-0.42496l-0.56953,-2.67574l0.27987,-4.39714l0.6747,-4.1107l0.61495,-1.81642',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547069129052',
#      'subID': '010919_6',
#      'age': 'age7',
#      'category': 'bird',
#      'condition': 'S',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/S_bird_sketch_age7_CDM_photodraw_e21547069129052.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '6',
#      'svg': 'M290.71875,231.42188l6.58341,1.54047l4.88099,2.01585l4.14879,3.23769l4.38681,5.20599l2.98784,3.50725l1.67698,2.27016l0.33518,1.2226l-3.83088,-0.19498l-2.33969,-3.72251l-1.0044,-5.01377l0.17498,-4.06874l4.16065,-4.42902l5.83935,-2.57098l3.54121,-1.06958l3.45879,0.06958l-1.02903,4.77717l-3.97097,3.22283l-24,11l-3.93241,2.2162l-3.06759,1.7838v-2',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'CDM_photodraw_e21547069129052',
#      'subID': '010919_6',
#      'age': 'age7',
#      'category': 'bird',
#      'condition': 'S',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/bird/S_bird_sketch_age7_CDM_photodraw_e21547069129052.png',
#      'ref_image_name': 'images_photocues/bird_3.png',
#      'stroke_count': '7',
#      'svg': 'M218.71875,256.42188l-2.34484,12.72832l-6.65516,11.27168l-3.75457,3.89571l-2.24714,2.4983l-0.99828,1.60599l1.125,0.375l1.875,-0.375l24,-1h1l0.96152,2.75054l-1.42236,3.35098l-7.4209,7.51638l-9.23003,6.95743l-5.88822,4.42466l0.30359,1.93442l2.62228,2.44107l3.15934,2.25333l1.91479,1.37118l2.53944,4.13965l0.52603,4.69305l-3.06547,9.16729',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'}],
#    'rois': [{'object': 'bird',
#      'label_name': 'Feather',
#      'part_num': '1',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Wing',
#      'part_num': '2',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Eye',
#      'part_num': '3',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Head',
#      'part_num': '4',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Body',
#      'part_num': '5',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Tail',
#      'part_num': '6',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Beak/mouth',
#      'part_num': '7',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Leg',
#      'part_num': '8',
#      'color': '#fed541'},
#     {'object': 'bird',
#      'label_name': 'Foot',
#      'part_num': '9',
#      'color': '#fed541'}]},
#   {'strokes': [{'session_id': 'CDM_photodraw_e21547849081297',
#      'subID': '011819_8',
#      'age': 'age6',
#      'category': 'cat',
#      'condition': 'P',
#      'filename': '/Users/brialong/Documents/GitHub/devphotodraw/analysis/step1_get_drawings/CDM_Drawings/photodraw2/photodraw2_all_sketches_svg_copy/cat/P_cat_sketch_age6_CDM_photodraw_e21547849081297.png',
#      'ref_image_name': 'images_photocues/cat_2.png',
#      'stroke_count': '1',
#      'svg': 'M527.71875,424.42188l10,-7l1.529,-0.13259l3.57219,-0.07823l10.52814,-0.02633l10.46347,0.09224l3.49136,0.06999l1.41583,0.07491l6,4l3.88563,4.16055l4.06947,7.31429l2.59192,7.57687l-0.54701,4.94829l-4.13466,1.44874l-6.42667,0.20014l-6.646,-0.3743l-4.79267,-0.27458l-21.05302,1.72968l-18.94698,6.27032h-6l-3.86498,4.28913l-3.13502,4.71087l-5.65957,3.2254l-9.38708,3.74681l-10.11376,3.7607l-7.83959,3.26709l-6.68662,1.54643l-8.19367,0.14371l-8.00353,0.04864l-6.11619,1.26122l-6.62132,1.90564l-7.87102,0.51048l-15.50766,-0.41613l-22.66719,1.15382l-22.33281,3.84618l-6.02683,1.22273l-8.15564,1.20639l-19.56763,1.69774l-18.69258,-0.36569l-7.06183,-1.3729l-4.49548,-2.38828l-3.05905,-0.7465l-3.46571,1.72188l-2.95333,2.48419l-1.52192,1.54043l-3.14063,1.10938l-4.35937,-0.10938l-4.35937,-0.10937l-3.14062,1.10938l-1.79762,0.85958l-3.75885,1.2129l-10.95171,2.64507l-11.44762,1.5363l-4.37874,-0.17307l-2.66546,-1.08078l-2.73907,-4.8152l-1.54325,-7.05849l-0.8255,-17.89443l-0.02159,-18.01037l-0.53836,-7.20341l-1.33223,-5.01809l-3.88751,-14.69054l-0.1401,-15.97276l0.3737,-16.14111l-2.34609,-15.19559l-21.75696,-70.18754l-7.4019,-36.32029l-2.84114,-37.49218l-0.8985,-11.20454l-2.1015,-10.79546l-0.95003,-17.34957l0.95003,-17.65043l-0.31985,-11.73636l0.80377,-5.73739l2.51609,-4.52626l3.87459,-1.20842l4.12541,-0.79158l14.51222,-3.87821l14.48355,1.72138l13.48567,6.0498l11.51856,9.10704l3.82951,4.92326l3.87323,6.27948l3.27186,5.67811l2.02541,3.11916l2.13649,1.32009l1.67893,-0.47342l2.46515,-4.0661l2.07486,-4.45639l2.64457,-0.32418l7.99852,5.75533l9.48807,3.33274l22.51341,1.91193l6.59387,0.80286l5.40613,0.19714l1.69238,-2.15934l1.68309,-3.86346l2.62453,-6.97721l7.72217,-13.14838l10.24049,-11.57105l12.75916,-6.96134l7.32419,-0.80441l7.95399,1.48517l20,9l2.88959,3.34156l2.74573,5.95081l1.42807,6.30462l-1.06339,4.40301l-6,8l-5.67014,5.34027l-6.32986,6.65973l-5.28071,9.12892l-6.43881,11.6568l-4.32905,12.26394l1.04856,10.95035l1.74536,1.86792l3.45142,2.57783l9.9687,6.44104l10.63596,6.74765l7.19856,5.36557l5.25958,2.25958l5.74042,2.74042l11.61001,12.94591l10.38999,14.05409l4.95738,9.23418l7.04262,7.76582l10.06404,8.28202l10.93596,8.71798l25.69379,14.44401l10.89619,9.44461l8.41002,12.11138l1.24754,5.03529l1.03937,8.14576l0.39592,8.05523l-0.68283,4.76371l-6.09771,5.68905l-5.90229,6.31095l-0.61635,5.24058l1.15182,7.04284l2.46453,13.71657',
#      'location': 'CDM',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'}],
#    'rois': [{'object': 'cat',
#      'label_name': 'Tail',
#      'part_num': '1',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Eye',
#      'part_num': '2',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Ear',
#      'part_num': '3',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Leg',
#      'part_num': '4',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Whisker',
#      'part_num': '5',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Head',
#      'part_num': '6',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Mouth',
#      'part_num': '7',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Nose',
#      'part_num': '8',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Body',
#      'part_num': '9',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Paw',
#      'part_num': '10',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Fur',
#      'part_num': '11',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Claw',
#      'part_num': '12',
#      'color': '#fed541'}]},
#   {'strokes': [{'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '1',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M61.21875,179.42188l-1.0823,-11.49391l1.45947,-11.60328l4.62283,-22.90281l4,-32l3,-29l0.19214,-5.71553l0.30527,-3.41565l0.50259,-1.86882l1.21615,2.41877l0.78385,3.58123l9,18l16.49054,25.80448l17.50946,25.19552l3.85256,6.19841l5.89263,9.06129l5.77004,8.18144l2.16321,2.59117l1.32156,0.96769" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '2',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M224.21875,161.42188l4.16239,-6.09715l2.61475,-7.17267l5.22286,-14.73018l11.19379,-25.48332l8.80621,-26.51668l3.62842,-12.83063l4.37158,-12.16937l0.72817,-2.07336l1.18308,-3.5612l1.22745,-3.24392l0.8613,-1.12152l0.33717,5.33951l-0.33717,5.66049l3,12l7.08186,32.2204l8.91814,31.7796l8,27l3,10l0.79593,2.58278l0.20407,0.41722" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '3',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M325.21875,200.42188l-6.82727,-8.34484l-8.39477,-7.27763l-20.09861,-11.50527l-22.18829,-7.6914l-21.49107,-4.18085l-23.45027,-2.67642l-26.4639,-1.93235l-27.58497,-0.03511l-26.81346,3.0153l-24.14938,7.21887l-10.48424,5.54614l-9.1085,7.02947l-7.4962,8.65695l-5.64733,10.42857l-3.56188,12.34433l-1.23987,14.40425l-0.46734,12.03501l0.46734,11.96499l6.61177,16.59889l9.38823,15.40111l11.13864,16.94215l12.47003,14.31826l13.77663,11.87173l15.05845,9.60254l16.31548,7.51071l17.54772,5.59622l18.75519,3.85909l19.93786,2.29931l33.38368,1.65857l16.74072,-1.37881l15.8756,-4.27976l14.12581,-9.21802l12.39457,-13.90398l10.38438,-15.84298l8.09525,-15.03503l8.43643,-24.78727l2.12059,-27.01519l-4.90792,-26.36396l-5.31236,-12.03803l-7.33674,-10.79555l-4.91405,-6.18155l-6.52298,-7.61872l-7.30446,-6.46858l-7.2585,-2.73115" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '4',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M63.21875,216.42188l39.19674,0.93533l38.80326,4.06467l21,2l1,1" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '5',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M25.21875,295.42188l50.56352,-11.91201l51.43648,-9.08799l33,-3l11,-1h4.18041h1.8921h-0.07251" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '6',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M94.21875,357.42188l11.26189,-7.35508l15.05868,-7.67974l15.6484,-7.16233l13.03103,-5.80285l18,-8l5.3049,-1.69679l2.39653,-0.90825l0.29856,-0.39495" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '7',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M279.21875,214.42188l18.12637,2.11478l18.41841,0.44953l18.39602,0.66737l18.0592,2.76832l24,5l6.48761,1.73533l2.74096,0.88417l0.77143,0.3805" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '8',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M287.21875,255.42188l14.88324,4.85761l16.10822,3.60048l32.00853,4.54191l13.25437,4.83417l6.43237,2.88489l5.31327,1.28093" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '9',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M280.21875,313.42188l46.26303,9.9275l46.73697,8.0725l31,6l4.00245,1.00162l5.494,1.33315l4.24578,1.16577l0.25778,0.49946" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '10',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M161.21875,251.42188l5.65506,-4.07202l9.36157,-5.44653l9.85325,-3.68725l4.10638,-0.20459l3.02374,1.4104l2.48426,3.08319l3.99254,5.07409l4.25414,4.74545l3.26906,2.09727" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '11',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M231.21875,251.42188l4.52062,-5.28203l5.56707,-2.708l12.24026,0.74777l10.32628,6.3689l3.17461,4.31841l1.17116,4.55494" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '12',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M203.21875,280.42188l10.31144,-1.22896l10.68856,0.22896l3,-1l2.65294,-0.26649l5.1219,-0.43587l4.98448,-0.33469l2.24069,0.03705l-3.43935,5.68631l-4.56065,5.31369l-3.1097,5.33897l-3.8903,4.66103l-4.43788,0.90817l-4.08397,-1.43596l-7.13525,-7.16358l-5.8067,-8.31789l-2.42328,-2.87885l-2.11292,-1.11188" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '13',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M221.21875,293.42188l0.94044,7.25937l-0.98022,5.92149l-6.63279,8.28546l-11.04651,4.3023l-13.28093,1.23138" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '14',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M237.21875,302.42188l7.29037,8.58497l8.28733,6.99056l9.49848,4.7028l10.92381,1.72168" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '15',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M215.21875,319.42188l5.28277,5.34297l6.71723,2.65703l9.2966,1.55735l6.58894,-1.81732l12.11446,-7.74003" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '16',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M185.21875,353.42188l-10.74401,5.79303l-8.25345,9.77547l-5.84832,12.6534l-3.5286,14.42682l-1.2943,15.09573l0.85458,14.66013l2.91803,13.12002l4.89607,10.4754l19.7775,23.20098l23.2225,19.79902l20.7793,12.70051l23.03002,8.59733l24.12536,5.19841l24.06532,2.50376l68.42433,3.62929l68.57567,-0.62929l15.99105,-2.27192l15.75538,-3.96011l31.25358,-8.76796l29.98395,-9.17068l14.26982,-6.90618l12.74623,-8.92314l9.4503,-8.99642l9.69412,-11.03029l17.7319,-26.31079l6.84387,-14.35479l4.69987,-14.53725l1.95892,-14.25685l-1.37898,-13.5136l-5.79746,-13.17596l-9.61939,-13.03775l-11.41096,-11.68089l-11.17218,-9.1054l-28.57733,-15.94757l-30.31691,-9.7255l-31.61979,-5.38897l-32.48597,-2.93796l-55.91278,-3.00059l-56.08722,-0.99941" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '17',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M230.21875,499.42188l-1.43914,3.02859l-2.25842,5.47864l-5.72805,15.17671l-5.26525,15.58474l-1.67992,5.98867l-0.62923,3.74264l0.30697,22.26962l3.69303,21.73038l9.39878,16.45635l15.11689,13.45066l18.35905,7.99716l9.62161,1.18857l9.50367,-1.09274l7.83099,-3.47214l8.13303,-6.16196l15.95039,-17.60109l13.49319,-19.9835l5.06152,-9.13997l3.53088,-7.64135l4.95605,-11.75825l4.87743,-13.84876l1.71069,-13.54526l-1.29722,-5.91068l-3.24695,-4.93705" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '18',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M390.21875,516.42188l-9.0282,11.21347l-6.92412,15.43393l-3.69796,16.61023l0.65028,14.74237l5.92753,14.67932l9.29952,10.64674l12.436,6.48371l15.33695,2.19023l7.21029,-0.00103l6.78971,-1.99897l13.49174,-11.3905l10.05647,-15.52431l6.28237,-17.5669l2.16942,-17.51828l-0.00941,-6.8033l-0.76568,-8.27186l-2.62814,-6.98428l-5.59677,-2.94057" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '19',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M501.21875,513.42188l-2.97368,4.35608l-2.82522,6.60212l-4.65988,17.17538l-2.43049,17.85859l-0.03848,7.45613l0.92775,5.5517l5.57237,9.28912l7.42763,7.71088l11.58715,9.13836l6.76543,2.52564l7.64743,-0.664l4.95639,-3.40651l4.4873,-5.7253l6.55631,-11.86819l7.21312,-19.15795l2.94395,-21.19076l-0.92877,-10.27732l-2.95582,-9.48908l-5.30279,-8.2687l-7.96969,-6.61618l-6.28647,-3.4474l-6.71353,-1.5526" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '20',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M570.21875,487.42188l-1.33895,4.59631l-1.16294,6.78562l-1.45617,17.27695l0.27286,17.44751l0.99835,6.99882l1.68685,4.89478l8.17504,9.80798l9.82496,8.19202l4.11258,3.15064l5.53223,3.697l5.95982,2.52318l5.39537,-0.37083l4.89242,-4.33196l3.42361,-6.35472l3.68397,-13.31332l1.50248,-14.39358l-1.93275,-12.97153l-5.96762,-11.53897l-10.60212,-10.09592l-17.06167,-11.42153l-9.41187,-4.7387l-9.52646,-2.83978l-4.11144,-0.50744l-6.04317,-0.7942l-5.46587,-1.14338l-2.37952,-1.55499" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'},
#     {'session_id': 'Tsinghua_photodraw_production1578462794400',
#      'subID': 'iPad 3_THU9F1',
#      'age': 9.99,
#      'category': 'cat',
#      'condition': 'S',
#      'filename': 'THU_sketches_and_metadata/cat_sketch_iPad 3_THU9F1_S.png',
#      'ref_image_name': 'images_photocues/cat_1.png',
#      'stroke_count': '21',
#      'svg': '<path xmlns="http://www.w3.org/2000/svg" d="M586.21875,409.42188l10.71956,-24.80545l7.44168,-11.08539l10.83876,-7.10915l5.68187,-0.2325l4.91633,2.74143l8.7489,10.37537l9.32535,10.18322l5.63689,2.50125l6.69066,-0.56876l2.59245,-2.10238l2.61606,-3.76907l3.79149,-7.12855l7.60656,-17.44911l3.39344,-18.55089l0.18307,-4.25905l0.05512,-6.02677l-0.81398,-5.38386l-2.42422,-2.33032" fill="none" fill-rule="nonzero" stroke="#000000" stroke-width="10" stroke-linecap="round" stroke-linejoin="miter" stroke-miterlimit="10" stroke-dasharray="" stroke-dashoffset="0" font-family="none" font-weight="none" font-size="none" text-anchor="none" style="mix-blend-mode: normal"/>',
#      'location': 'THU',
#      'group': 'animals',
#      'bin': '0',
#      'bin_9': '0'}],
#    'rois': [{'object': 'cat',
#      'label_name': 'Tail',
#      'part_num': '1',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Eye',
#      'part_num': '2',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Ear',
#      'part_num': '3',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Leg',
#      'part_num': '4',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Whisker',
#      'part_num': '5',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Head',
#      'part_num': '6',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Mouth',
#      'part_num': '7',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Nose',
#      'part_num': '8',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Body',
#      'part_num': '9',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Paw',
#      'part_num': '10',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Fur',
#      'part_num': '11',
#      'color': '#fed541'},
#     {'object': 'cat',
#      'label_name': 'Claw',
#      'part_num': '12',
#      'color': '#fed541'}]}],
#  'batch_id': '0',
#  'games': []}

# %%
# db.drop_collection('devphotodraw_animals')
